# %%
import os
import torch
print("CUDA available:", torch.cuda.is_available())
print("Current working directory:", os.getcwd())
# Out:
# CUDA available: True
# Current working directory: /kaggle/working

# %%
# 拉取代码
# !git clone https://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@github.com/JitingSu/FinalLab_ai.git /kaggle/working/project
# Out:
# Cloning into '/kaggle/working/project'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 227 (delta 2), reused 6 (delta 2), pack-reused 220 (from 1)
# Receiving objects: 100% (227/227), 71.74 KiB | 3.12 MiB/s, done.
# Resolving deltas: 100% (130/130), done.

# %%
# 数据集导入
import shutil
import os

source_dir = '/kaggle/input/project5/dataset'
target_dir = '/kaggle/working/dataset'


if os.path.exists(target_dir):
    shutil.rmtree(target_dir)


shutil.copytree(source_dir, target_dir)

print(f"Files copied from {source_dir} to {target_dir}")
# Out:
# Files copied from /kaggle/input/project5/dataset to /kaggle/working/dataset

# %%
# 拉取更新仓库内容
# !cd /kaggle/working/project && git pull
# Out:
# Already up to date.

# %%
# 登录wandb
import wandb

wandb.login(key="5db63b7847135a142daee6a4face770998aec49a")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ziyul707 (ziyul707-east-china-normal-university). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# 正常训练过程
# !python /kaggle/working/project/main.py
# Out:
# wandb: Currently logged in as: ziyul707 (ziyul707-east-china-normal-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250121_105844-iel5209n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stellar-star-48
# wandb: ⭐️ View project at https://wandb.ai/ziyul707-east-china-normal-university/FinalLab
# wandb: 🚀 View run at https://wandb.ai/ziyul707-east-china-normal-university/FinalLab/runs/iel5209n
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 186kB/s]
# vocab.txt: 100%|█████████████████████████████| 232k/232k [00:00<00:00, 7.53MB/s]
# tokenizer.json: 100%|████████████████████████| 466k/466k [00:00<00:00, 21.7MB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 1.99MB/s]
# model.safetensors: 100%|██████████████████████| 440M/440M [00:02<00:00, 216MB/s]
# ...

# %%
# 消融实验
# !python /kaggle/working/project/compare.py
# Out:
# wandb: Currently logged in as: ziyul707 (ziyul707-east-china-normal-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250121_111352-azmc7u6n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run eager-feather-49
# wandb: ⭐️ View project at https://wandb.ai/ziyul707-east-china-normal-university/FinalLab
# wandb: 🚀 View run at https://wandb.ai/ziyul707-east-china-normal-university/FinalLab/runs/azmc7u6n
# Epoch 1/10 - Training: 100%|███████████████| 100/100 [01:21<00:00,  1.23batch/s]
# Epoch [1/10], Loss: 0.8078, Accuracy: 64.47%
# Validation: 100%|████████████████████████████| 25/25 [00:06<00:00,  3.66batch/s]
# Validation Accuracy: 68.38%
# Epoch 2/10 - Training: 100%|███████████████| 100/100 [01:19<00:00,  1.26batch/s]
# Epoch [2/10], Loss: 0.6275, Accuracy: 73.41%
# ...
